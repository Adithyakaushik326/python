# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
mnist  = tf.keras.datasets.mnist

# %%
model = tf.keras.models.Sequential()

# %%
x_train = tf.keras.utils.normalize(x_train)
x_test = tf.keras.utils.normalize(x_test)

# %%
(x_train,y_train),(x_test,y_test)=mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step

# %%
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))

# %%
model.compile(optimizer='adam',
             loss = 'sparse_categorical_crossentropy',
             metrics = ['accuracy'])

# %%
model.fit(x_train,y_train,epochs=3)
# Out:
# Train on 60000 samples
# Epoch 1/3
# 60000/60000 [==============================] - 14s 234us/sample - loss: 0.2615 - accuracy: 0.9208
# Epoch 2/3
# 60000/60000 [==============================] - 10s 159us/sample - loss: 0.1101 - accuracy: 0.9661
# Epoch 3/3
# 60000/60000 [==============================] - 10s 161us/sample - loss: 0.0774 - accuracy: 0.9760

# %%
val_loss,val_acc= model.evaluate(x_test,y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %%
print(val_loss,val_acc)
# Out:
# 0.09317408600971103 0.9705

# %%
pred = model.predict(x_test)

# %%
print(np.argmax(pred[13]))
# Out:
# 0

# %%
plt.imshow(x_test[13])

# %%
import pickle

# %%
x = pickle.load(open('X.pickle','rb'))

# %%
len(x)
# Out:
# 25000
